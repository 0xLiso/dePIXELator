# %%
from export_film import *

# %%
v = VIPFile("SN00002.VIP", 0x20, 10000)

# %%
v.show_info(0, -1, filter_by=["🎨","🖼️"])
# Out:
# 000000: [   580] 44 02 00 02 02 00 60 c0  🎨
# 000553: [   580] 44 02 00 02 72 01 60 c0  🎨
# 000665: [   580] 44 02 00 02 bc 01 60 c0  🎨
# 000753: [   580] 44 02 00 02 f6 01 60 c0  🎨
# 000856: [   580] 44 02 00 02 3a 02 60 c0  🎨
# 000905: [   580] 44 02 00 02 5a 02 60 c0  🎨
# 000957: [   580] 44 02 00 02 7c 02 60 c0  🎨
# 001027: [   580] 44 02 00 02 aa 02 60 c0  🎨
# 001148: [   580] 44 02 00 02 fa 02 60 c0  🎨
# 001194: [   580] 44 02 00 02 18 03 60 c0  🎨
# 001279: [   580] 44 02 00 02 50 03 60 c0  🎨
# 001331: [   580] 44 02 00 02 72 03 60 c0  🎨
# 001410: [   580] 44 02 00 02 a6 03 60 c0  🎨
# 001480: [   580] 44 02 00 02 d4 03 60 c0  🎨
# 001568: [   580] 44 02 00 02 0e 04 60 c0  🎨
# 001596: [   580] 44 02 00 02 20 04 60 c0  🎨
# 001651: [   580] 44 02 00 02 44 04 60 c0  🎨
# 001751: [   580] 44 02 00 02 86 04 60 c0  🎨
# 001830: [   580] 44 02 00 02 ba 04 60 c0  🎨
# 001831: [ 31920] b0 7c 02 03 ba 04 60 c0  🖼️
# 001957: [   580] 44 02 00 02 0e 05 60 c0  🎨
# ...

# %%
pal = v.get_palette(1830)

# %%
f = v.draw_frame_type03(1831)

# %%
frame = v.apply_palette(pal, f)

# %%
plt.imshow(frame)
